tif
# /kaggle/input/datasets/mennathabett/multispectral-satellite-imagery-images/images/157.tif
# /kaggle/input/datasets/mennathabett/multispectral-satellite-imagery-images/images/62.tif
# /kaggle/input/datasets/mennathabett/multispectral-satellite-imagery-images/images/11.tif
# /kaggle/input/datasets/mennathabett/multispectral-satellite-imagery-images/images/91.tif
# /kaggle/input/datasets/mennathabett/multispectral-satellite-imagery-images/images/188.tif
# /kaggle/input/datasets/mennathabett/multispectral-satellite-imagery-images/images/234.tif
# /kaggle/input/datasets/mennathabett/multispectral-satellite-imagery-images/images/135.tif
# /kaggle/input/datasets/mennathabett/multispectral-satellite-imagery-images/images/186.tif
# /kaggle/input/datasets/mennathabett/multispectral-satellite-imagery-images/images/277.tif
# /kaggle/input/datasets/mennathabett/multispectral-satellite-imagery-images/images/52.tif
# /kaggle/input/datasets/mennathabett/multispectral-satellite-imagery-images/images/264.tif
# /kaggle/input/datasets/mennathabett/multispectral-satellite-imagery-images/images/253.tif
# /kaggle/input/datasets/mennathabett/multispectral-satellite-imagery-images/images/73.tif
# /kaggle/input/datasets/mennathabett/multispectral-satellite-imagery-images/images/181.tif
# /kaggle/input/datasets/mennathabett/multispectral-satellite-imagery-images/images/8.tif
# /kaggle/input/datasets/mennathabett/multispectral-satellite-imagery-images/images/120.tif
# /kaggle/input/datasets/mennathabett/multispectral-satellite-imagery-images/images/102.tif
# /kaggle/input/datasets/mennathabett/multispectral-satellite-imagery-images/images/290.tif
# /kaggle/input/datasets/mennathabett/multispectral-satellite-imagery-images/images/205.tif
# /kaggle/input/datasets/mennathabett/multispectral-satellite-imagery-images/images/137.tif
# /kaggle/input/datasets/mennathabett/multispectral-satellite-imagery-images/images/43.tif
# /kaggle/input/datasets/mennathabett/multispectral-satellite-imagery-images/images/128.tif
# /kaggle/input/datasets/mennathabett/multispectral-satellite-imagery-images/images/251.tif

# %% [markdown]
# # Water Segmentation — Pretrained Encoder vs Scratch U-Net
#
# **Objective:** This is a comparative study that adapts a pretrained segmentation backbone (ResNet34 encoder, ImageNet weights) to accept 12-channel multispectral input, fine-tune it on the water segmentation dataset, and compare it against from-scratch U-Net using the metrics: IoU, F1, Precision, Recall
#
# This notebook uses:
# - A pretrained `segmentation-models-pytorch` U-Net (ResNet34 encoder) adapted to 12 input channels
# - Two fine-tuning strategies compared: **full fine-tuning** vs **encoder-frozen warmup + unfreeze**
# - A direct comparison table against the from-scratch U-Net model

# %% [markdown]
# # Setup

# %%
# !pip install segmentation-models-pytorch --quiet

# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import rasterio
from PIL import Image

import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import Dataset, DataLoader
from sklearn.model_selection import train_test_split

import segmentation_models_pytorch as smp

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("Using device:", device)

SEED = 42
torch.manual_seed(SEED)
np.random.seed(SEED)
# Out:
# Using device: cuda

# %% [markdown]
# # Step 1: EDA

# %% [markdown]
# ## Step 1.1 — Sanity Check on One File

# %%
IMAGES_DIR = "/kaggle/input/datasets/mennathabett/multispectral-satellite-imagery-images/images"
LABELS_DIR = "/kaggle/input/datasets/mennathabett/multispectral-satellite-imagery-labels/labels"

# Pick one sample to inspect first
sample_img_path = os.path.join(IMAGES_DIR, "5.tif")

with rasterio.open(sample_img_path) as src:
    img = src.read()  # shape: (bands, H, W)
    print("Shape:", img.shape)
    print("Dtype:", img.dtype)
    print("Min per band:", img.min(axis=(1, 2)))
    print("Max per band:", img.max(axis=(1, 2)))
    print("Mean per band:", img.mean(axis=(1, 2)))
# Out:
# Shape: (12, 128, 128)
# Dtype: int16
# Min per band: [-37  -1  43  44 334 152  75  64 754 739  10   0]
# Max per band: [ 808 2364 2977 3400 3540 4897 3876  192 1203 1197   60    0]
# Mean per band: [ 234.57672119  303.57824707  464.32879639  547.159729   1580.40081787
#  1613.9944458  1059.38250732   64.45117188  959.87329102  946.01519775
#    19.03686523    0.        ]
# /usr/local/lib/python3.12/dist-packages/rasterio/__init__.py:367: NotGeoreferencedWarning: Dataset has no geotransform, gcps, or rpcs. The identity matrix will be returned.
#   dataset = DatasetReader(path, driver=driver, sharing=sharing, thread_safe=thread_safe, **kwargs)

# %% [markdown]
# ## Step 1.2 — Dataset-Wide Structure Check

# %%
image_files = sorted([f for f in os.listdir(IMAGES_DIR) if f.endswith(".tif")])
print("Number of image samples:", len(image_files))

shapes = set()
dtypes = set()
for f in image_files:
    with rasterio.open(os.path.join(IMAGES_DIR, f)) as src:
        shapes.add(src.read().shape)
        dtypes.add(src.dtypes[0])

print("Unique shapes found:", shapes)
print("Unique dtypes found:", dtypes)
# Out:
# Number of image samples: 306
# Unique shapes found: {(12, 128, 128)}
# Unique dtypes found: {'int16'}

# %% [markdown]
# ## Step 1.3 — Matching Images to Labels

# %%
def get_clean_label_files(labels_dir):
    """keeping only label files matching pattern: <number>.png (no underscore)"""
    all_files = os.listdir(labels_dir)
    clean = [f for f in all_files if f.endswith(".png") and "_" not in f]
    return sorted(clean, key=lambda x: int(x.split(".")[0]))

label_files = get_clean_label_files(LABELS_DIR)
print("Number of clean label files:", len(label_files))
print(label_files[:10])
# Out:
# Number of clean label files: 306
# ['0.png', '1.png', '2.png', '3.png', '4.png', '5.png', '6.png', '7.png', '8.png', '9.png']

# %%
image_ids = sorted([int(f.split(".")[0]) for f in image_files])
label_ids = sorted([int(f.split(".")[0]) for f in label_files])

print("Image IDs range:", min(image_ids), "-", max(image_ids), "| count:", len(image_ids))
print("Label IDs range:", min(label_ids), "-", max(label_ids), "| count:", len(label_ids))
print("IDs in images but not labels:", set(image_ids) - set(label_ids))
print("IDs in labels but not images:", set(label_ids) - set(image_ids))
# Out:
# Image IDs range: 0 - 305 | count: 306
# Label IDs range: 0 - 305 | count: 306
# IDs in images but not labels: set()
# IDs in labels but not images: set()

# %% [markdown]
# ## Step 1.4 — Visualize All 12 Bands for One Sample

# %%
def load_tif(path):
    with rasterio.open(path) as src:
        return src.read()  # (12, H, W)

def stretch(band, low=2, high=98):
    """Percentile stretch for visualization"""
    lo, hi = np.percentile(band, [low, high])
    band = np.clip(band, lo, hi)
    if hi - lo == 0:
        return np.zeros_like(band, dtype=np.float32)
    return (band - lo) / (hi - lo)

sample_id = 13  # a sample with visible water
img = load_tif(os.path.join(IMAGES_DIR, f"{sample_id}.tif"))

fig, axes = plt.subplots(3, 4, figsize=(16, 12))
for i, ax in enumerate(axes.flat):
    band_stretched = stretch(img[i])
    ax.imshow(band_stretched, cmap='gray')
    ax.set_title(f"Band {i}")
    ax.axis('off')
plt.suptitle(f"Sample {sample_id} - All 12 Bands")
plt.tight_layout()
plt.savefig("band_visualization.png", dpi=100)
plt.show()

# %% [markdown]
# ## Step 1.5 — RGB Composite + Mask Overlay

# %%
def load_mask(sample_id):
    mask = np.array(Image.open(os.path.join(LABELS_DIR, f"{sample_id}.png")))
    return mask

# RGB index - Sentinel-2 L2A order is often:
# RGB = indices 3,2,1 (Red,Green,Blue)
rgb = np.stack([stretch(img[3]), stretch(img[2]), stretch(img[1])], axis=-1)
mask = load_mask(sample_id)

fig, axes = plt.subplots(1, 3, figsize=(15, 5))
axes[0].imshow(rgb)
axes[0].set_title("RGB composite (bands 3,2,1)")
axes[1].imshow(mask, cmap='gray')
axes[1].set_title("Label mask")
axes[2].imshow(rgb)
axes[2].imshow(mask, cmap='Reds', alpha=0.4)
axes[2].set_title("Overlay")
for ax in axes: ax.axis('off')
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Step 1.6 — Label Class Distribution (full dataset)

# %%
water_ratios = []
for f in label_files:
    m = np.array(Image.open(os.path.join(LABELS_DIR, f)))
    m = (m > 0).astype(np.uint8)  # ensure binary
    water_ratios.append(m.mean())

water_ratios = np.array(water_ratios)
print("Unique mask values check (sample):", np.unique(np.array(Image.open(os.path.join(LABELS_DIR, label_files[0])))))
print("Mean water % per image:", water_ratios.mean() * 100)
print("Images with 0% water:", (water_ratios == 0).sum(), "/", len(water_ratios))
print("Images with >20% water:", (water_ratios > 0.2).sum())

plt.figure(figsize=(8,4))
plt.hist(water_ratios * 100, bins=30)
plt.xlabel("% water pixels per image")
plt.ylabel("count")
plt.title("Water pixel distribution across dataset")
plt.show()
# Out:
# Unique mask values check (sample): [0 1]
# Mean water % per image: 25.97528594771242
# Images with 0% water: 45 / 306
# Images with >20% water: 143

# %% [markdown]
# ## Step 1.7 — Quick check: is band 11 zero everywhere?

# %%
band_all_zero = []
for f in image_files:
    with rasterio.open(os.path.join(IMAGES_DIR, f)) as src:
        img = src.read()
        band_all_zero.append((img == 0).all(axis=(1,2)))

band_all_zero = np.array(band_all_zero)  # (306, 12)
print("Fraction of images where each band is ALL zero:")
for i in range(12):
    print(f"Band {i}: {band_all_zero[:,i].mean()*100:.1f}%")
# Out:
# Fraction of images where each band is ALL zero:
# Band 0: 0.0%
# Band 1: 0.0%
# Band 2: 0.0%
# Band 3: 0.0%
# Band 4: 0.0%
# Band 5: 0.0%
# Band 6: 0.0%
# Band 7: 0.0%
# Band 8: 0.0%
# Band 9: 0.0%
# Band 10: 0.0%
# Band 11: 18.6%

# %% [markdown]
# # Step 2 — Preprocessing Pipeline

# %%
import torch
from torch.utils.data import Dataset, DataLoader

# %% [markdown]
# ## Step 2.1: Compute per-band mean/std across the training set

# %%
def compute_band_stats(image_files, images_dir):
    all_bands = []  # will hold (306, 12) mean and std per image, then aggregate
    sums = np.zeros(12)
    sq_sums = np.zeros(12)
    pixel_count = 0

    for f in image_files:
        with rasterio.open(os.path.join(images_dir, f)) as src:
            img = src.read().astype(np.float64)  # (12,128,128)
        sums += img.sum(axis=(1,2))
        sq_sums += (img ** 2).sum(axis=(1,2))
        pixel_count += img.shape[1] * img.shape[2]

    mean = sums / pixel_count
    std = np.sqrt(sq_sums / pixel_count - mean ** 2)
    return mean, std

band_mean, band_std = compute_band_stats(image_files, IMAGES_DIR)
print("Per-band mean:", band_mean)
print("Per-band std:", band_std)

# saving for using at inference time
np.save("band_mean.npy", band_mean)
np.save("band_std.npy", band_std)
# Out:
# Per-band mean: [ 396.46767291  494.62102873  822.31978453  973.67496126 2090.11099642
#  1964.05056902 1351.27395331  102.73963041  141.80390641  300.74136253
#    35.10253308    9.75332642]
# Per-band std: [ 270.06659307  325.97919685  418.12163021  586.70297516 1055.9846072
#  1191.42226561  961.76258759   48.80401527 1364.98112115  496.03880723
#    20.18452457   27.75830662]

# %% [markdown]
# ## Step 2.2 — Train/Val Split (stratified by water presence)

# %%
from sklearn.model_selection import train_test_split

ids = np.array([int(f.split('.')[0]) for f in label_files])
has_water = (water_ratios > 0).astype(int) 

train_ids, val_ids = train_test_split(
    ids, test_size=0.2, random_state=42, stratify=has_water
)
print("Train:", len(train_ids), "Val:", len(val_ids))
print("Train water-present ratio:", has_water[train_ids].mean())
print("Val water-present ratio:", has_water[val_ids].mean())
# Out:
# Train: 244 Val: 62
# Train water-present ratio: 0.8524590163934426
# Val water-present ratio: 0.8548387096774194

# %% [markdown]
# ## Step 2.3 — PyTorch Dataset Class

# %%
class WaterSegDataset(Dataset):
    def __init__(self, ids, images_dir, labels_dir, band_mean, band_std):
        self.ids = ids
        self.images_dir = images_dir
        self.labels_dir = labels_dir
        self.band_mean = band_mean.reshape(12, 1, 1)
        self.band_std = band_std.reshape(12, 1, 1)

    def __len__(self):
        return len(self.ids)

    def __getitem__(self, idx):
        sample_id = self.ids[idx]

        with rasterio.open(os.path.join(self.images_dir, f"{sample_id}.tif")) as src:
            img = src.read().astype(np.float32)  # (12, 128, 128)

        mask = np.array(Image.open(os.path.join(self.labels_dir, f"{sample_id}.png")))
        mask = (mask > 0).astype(np.float32)  # ensure binary (0/1)

        # Per-band normalization
        img = (img - self.band_mean) / (self.band_std + 1e-8)

        img_tensor = torch.from_numpy(img).float()          # (12,128,128)
        mask_tensor = torch.from_numpy(mask).float().unsqueeze(0)  # (1,128,128)

        assert img_tensor.shape == (12, 128, 128), f"Bad shape: {img_tensor.shape}"

        return img_tensor, mask_tensor


# Recompute stats on train split only
band_mean_train, band_std_train = compute_band_stats(
    [f"{i}.tif" for i in train_ids], IMAGES_DIR
)

train_ds = WaterSegDataset(train_ids, IMAGES_DIR, LABELS_DIR, band_mean_train, band_std_train)
val_ds = WaterSegDataset(val_ids, IMAGES_DIR, LABELS_DIR, band_mean_train, band_std_train)

train_loader = DataLoader(train_ds, batch_size=16, shuffle=True)
val_loader = DataLoader(val_ds, batch_size=16, shuffle=False)

# Sanity check
x, y = next(iter(train_loader))
print("Batch image shape:", x.shape)   
print("Batch mask shape:", y.shape)  
print("Image dtype/range:", x.dtype, x.min().item(), x.max().item())
print("Mask unique values:", torch.unique(y))
# Out:
# /usr/local/lib/python3.12/dist-packages/rasterio/__init__.py:367: NotGeoreferencedWarning: Dataset has no geotransform, gcps, or rpcs. The identity matrix will be returned.
#   dataset = DatasetReader(path, driver=driver, sharing=sharing, thread_safe=thread_safe, **kwargs)
# Batch image shape: torch.Size([16, 12, 128, 128])
# Batch mask shape: torch.Size([16, 1, 128, 128])
# Image dtype/range: torch.float32 -3.412074327468872 15.305581092834473
# Mask unique values: tensor([0., 1.])

# %% [markdown]
# # Step 3 — U-Net Implementation

# %% [markdown]
# ## Step 3.1 — Model Architecture

# %%
import torch
import torch.nn as nn

class DoubleConv(nn.Module):
    """(Conv -> BN -> ReLU) x 2"""
    def __init__(self, in_ch, out_ch):
        super().__init__()
        self.block = nn.Sequential(
            nn.Conv2d(in_ch, out_ch, kernel_size=3, padding=1),
            nn.BatchNorm2d(out_ch),
            nn.ReLU(inplace=True),
            nn.Conv2d(out_ch, out_ch, kernel_size=3, padding=1),
            nn.BatchNorm2d(out_ch),
            nn.ReLU(inplace=True),
        )

    def forward(self, x):
        return self.block(x)


class Down(nn.Module):
    """Maxpool -> DoubleConv"""
    def __init__(self, in_ch, out_ch):
        super().__init__()
        self.block = nn.Sequential(
            nn.MaxPool2d(2),
            DoubleConv(in_ch, out_ch)
        )

    def forward(self, x):
        return self.block(x)


class Up(nn.Module):
    """Upsample -> concat skip -> DoubleConv"""
    def __init__(self, in_ch, out_ch):
        super().__init__()
        self.up = nn.ConvTranspose2d(in_ch, in_ch // 2, kernel_size=2, stride=2)
        self.conv = DoubleConv(in_ch, out_ch)  # in_ch because concat doubles channels

    def forward(self, x, skip):
        x = self.up(x)
        # Handle any off-by-one size mismatch from odd input dims
        diffY = skip.size(2) - x.size(2)
        diffX = skip.size(3) - x.size(3)
        x = nn.functional.pad(x, [diffX // 2, diffX - diffX // 2,
                                   diffY // 2, diffY - diffY // 2])
        x = torch.cat([skip, x], dim=1)
        return self.conv(x)


class UNet(nn.Module):
    def __init__(self, in_channels=12, out_channels=1, base_ch=64):
        super().__init__()
        self.inc = DoubleConv(in_channels, base_ch)          # 128 -> 128
        self.down1 = Down(base_ch, base_ch * 2)               # 128 -> 64
        self.down2 = Down(base_ch * 2, base_ch * 4)            # 64 -> 32
        self.down3 = Down(base_ch * 4, base_ch * 8)            # 32 -> 16
        self.down4 = Down(base_ch * 8, base_ch * 16)           # 16 -> 8  (bottleneck)

        self.up1 = Up(base_ch * 16, base_ch * 8)
        self.up2 = Up(base_ch * 8, base_ch * 4)
        self.up3 = Up(base_ch * 4, base_ch * 2)
        self.up4 = Up(base_ch * 2, base_ch)

        self.outc = nn.Conv2d(base_ch, out_channels, kernel_size=1)

        self._init_weights()

    def _init_weights(self):
        for m in self.modules():
            if isinstance(m, nn.Conv2d) or isinstance(m, nn.ConvTranspose2d):
                nn.init.kaiming_normal_(m.weight, mode='fan_out', nonlinearity='relu')
                if m.bias is not None:
                    nn.init.zeros_(m.bias)
            elif isinstance(m, nn.BatchNorm2d):
                nn.init.ones_(m.weight)
                nn.init.zeros_(m.bias)

    def forward(self, x):
        x1 = self.inc(x)      # (B, 64, 128,128)
        x2 = self.down1(x1)   # (B, 128, 64,64)
        x3 = self.down2(x2)   # (B, 256, 32,32)
        x4 = self.down3(x3)   # (B, 512, 16,16)
        x5 = self.down4(x4)   # (B, 1024, 8,8)  bottleneck

        x = self.up1(x5, x4)  # -> (B, 512, 16,16)
        x = self.up2(x, x3)   # -> (B, 256, 32,32)
        x = self.up3(x, x2)   # -> (B, 128, 64,64)
        x = self.up4(x, x1)   # -> (B, 64, 128,128)

        logits = self.outc(x) # (B, 1, 128,128) - raw logits, sigmoid applied in loss/eval
        return logits

# %% [markdown]
# ## Step 3.2 — Sanity Check the Model

# %%
model = UNet(in_channels=12, out_channels=1, base_ch=64)
x = torch.randn(4, 12, 128, 128)
out = model(x)
print("Output shape:", out.shape)  # expect (4, 1, 128, 128)

n_params = sum(p.numel() for p in model.parameters())
print(f"Total parameters: {n_params:,}")
# Out:
# Output shape: torch.Size([4, 1, 128, 128])
# Total parameters: 31,048,705

# %% [markdown]
# # Step 4: Training Loop + Loss + Evaluation Metrics

# %% [markdown]
# ## Step 4.1 — Loss Function (BCE + Dice)

# %%
import torch.nn.functional as F

class BCEDiceLoss(nn.Module):
    def __init__(self, bce_weight=0.5, smooth=1e-6):
        super().__init__()
        self.bce_weight = bce_weight
        self.smooth = smooth
        self.bce = nn.BCEWithLogitsLoss()

    def forward(self, logits, targets):
        bce_loss = self.bce(logits, targets)

        probs = torch.sigmoid(logits)
        probs_flat = probs.view(probs.size(0), -1)
        targets_flat = targets.view(targets.size(0), -1)

        intersection = (probs_flat * targets_flat).sum(dim=1)
        dice_score = (2. * intersection + self.smooth) / (
            probs_flat.sum(dim=1) + targets_flat.sum(dim=1) + self.smooth
        )
        dice_loss = 1 - dice_score.mean()

        return self.bce_weight * bce_loss + (1 - self.bce_weight) * dice_loss

# %% [markdown]
# ## Step 4.2 — Evaluation Metrics (IoU, Precision, Recall, F1)

# %%
def compute_metrics(logits, targets, threshold=0.5, smooth=1e-6):
    probs = torch.sigmoid(logits)
    preds = (probs > threshold).float()

    preds_flat = preds.view(-1)
    targets_flat = targets.view(-1)

    tp = (preds_flat * targets_flat).sum().item()
    fp = (preds_flat * (1 - targets_flat)).sum().item()
    fn = ((1 - preds_flat) * targets_flat).sum().item()

    iou = (tp + smooth) / (tp + fp + fn + smooth)
    precision = (tp + smooth) / (tp + fp + smooth)
    recall = (tp + smooth) / (tp + fn + smooth)
    f1 = (2 * precision * recall) / (precision + recall + smooth)

    return {"iou": iou, "precision": precision, "recall": recall, "f1": f1}

# %% [markdown]
# ## Step 4.3 — Training Loop

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("Using device:", device)

model = UNet(in_channels=12, out_channels=1, base_ch=64).to(device)
criterion = BCEDiceLoss(bce_weight=0.5)
optimizer = torch.optim.Adam(model.parameters(), lr=1e-3)
scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer, mode='min', factor=0.5, patience=3)

NUM_EPOCHS = 100
EARLY_STOP_PATIENCE = 15  # stop if val IoU doesn't improve for this many epochs

best_val_iou = 0.0
epochs_no_improve = 0
history = {"train_loss": [], "val_loss": [], "val_iou": []}

for epoch in range(NUM_EPOCHS):
    # Train
    model.train()
    train_loss = 0.0
    for imgs, masks in train_loader:
        imgs, masks = imgs.to(device), masks.to(device)

        optimizer.zero_grad()
        logits = model(imgs)
        loss = criterion(logits, masks)
        loss.backward()
        optimizer.step()

        train_loss += loss.item() * imgs.size(0)

    train_loss /= len(train_ds)

    # Validate
    model.eval()
    val_loss = 0.0
    metric_accum = {"iou": 0.0, "precision": 0.0, "recall": 0.0, "f1": 0.0}

    with torch.no_grad():
        for imgs, masks in val_loader:
            imgs, masks = imgs.to(device), masks.to(device)
            logits = model(imgs)
            loss = criterion(logits, masks)
            val_loss += loss.item() * imgs.size(0)

            batch_metrics = compute_metrics(logits, masks)
            for k in metric_accum:
                metric_accum[k] += batch_metrics[k] * imgs.size(0)

    val_loss /= len(val_ds)
    for k in metric_accum:
        metric_accum[k] /= len(val_ds)

    scheduler.step(val_loss)

    history["train_loss"].append(train_loss)
    history["val_loss"].append(val_loss)
    history["val_iou"].append(metric_accum["iou"])

    print(f"Epoch {epoch+1}/{NUM_EPOCHS} | "
          f"Train Loss: {train_loss:.4f} | Val Loss: {val_loss:.4f} | "
          f"Val IoU: {metric_accum['iou']:.4f} | Val F1: {metric_accum['f1']:.4f} | "
          f"Val Precision: {metric_accum['precision']:.4f} | Val Recall: {metric_accum['recall']:.4f}")

    if metric_accum["iou"] > best_val_iou:
        best_val_iou = metric_accum["iou"]
        epochs_no_improve = 0
        torch.save(model.state_dict(), "best_unet_water_seg.pth")
    else:
        epochs_no_improve += 1
        if epochs_no_improve >= EARLY_STOP_PATIENCE:
            print(f"\nEarly stopping triggered at epoch {epoch+1} "
                  f"(no improvement in val IoU for {EARLY_STOP_PATIENCE} epochs).")
            break

print(f"\nTraining complete. Best Validation IoU: {best_val_iou:.4f}")
# Out:
# Using device: cuda
# Epoch 1/100 | Train Loss: 0.5968 | Val Loss: 4.3723 | Val IoU: 0.5568 | Val F1: 0.7124 | Val Precision: 0.8617 | Val Recall: 0.6172
# Epoch 2/100 | Train Loss: 0.4249 | Val Loss: 0.3787 | Val IoU: 0.7191 | Val F1: 0.8365 | Val Precision: 0.8901 | Val Recall: 0.7921
# Epoch 3/100 | Train Loss: 0.4000 | Val Loss: 0.3790 | Val IoU: 0.7118 | Val F1: 0.8313 | Val Precision: 0.9178 | Val Recall: 0.7627
# Epoch 4/100 | Train Loss: 0.3967 | Val Loss: 0.3768 | Val IoU: 0.7055 | Val F1: 0.8269 | Val Precision: 0.8454 | Val Recall: 0.8115
# Epoch 5/100 | Train Loss: 0.3962 | Val Loss: 0.3765 | Val IoU: 0.7067 | Val F1: 0.8277 | Val Precision: 0.9199 | Val Recall: 0.7559
# Epoch 6/100 | Train Loss: 0.3842 | Val Loss: 0.3748 | Val IoU: 0.7017 | Val F1: 0.8245 | Val Precision: 0.8388 | Val Recall: 0.8137
# Epoch 7/100 | Train Loss: 0.3829 | Val Loss: 0.3621 | Val IoU: 0.7188 | Val F1: 0.8363 | Val Precision: 0.8798 | Val Recall: 0.8001
# Epoch 8/100 | Train Loss: 0.3765 | Val Loss: 0.3715 | Val IoU: 0.7101 | Val F1: 0.8302 | Val Precision: 0.8514 | Val Recall: 0.8132
# Epoch 9/100 | Train Loss: 0.3764 | Val Loss: 0.3549 | Val IoU: 0.7279 | Val F1: 0.8423 | Val Precision: 0.8758 | Val Recall: 0.8137
# Epoch 97/100 | Train Loss: 0.2708 | Val Loss: 0.2704 | Val IoU: 0.8019 | Val F1: 0.8900 | Val Precision: 0.9048 | Val Recall: 0.8770
# Epoch 98/100 | Train Loss: 0.2772 | Val Loss: 0.2723 | Val IoU: 0.7989 | Val F1: 0.8881 | Val Precision: 0.9098 | Val Recall: 0.8685
# Epoch 99/100 | Train Loss: 0.2742 | Val Loss: 0.2706 | Val IoU: 0.8039 | Val F1: 0.8912 | Val Precision: 0.9033 | Val Recall: 0.8807
# Epoch 100/100 | Train Loss: 0.2732 | Val Loss: 0.2707 | Val IoU: 0.7993 | Val F1: 0.8884 | Val Precision: 0.9157 | Val Recall: 0.8638
#
# Training complete. Best Validation IoU: 0.8039

# %% [markdown]
# ## Step 4.4 — Final Reported Metrics

# %%
model.load_state_dict(torch.load("best_unet_water_seg.pth"))
model.eval()

final_metrics = {"iou": 0.0, "precision": 0.0, "recall": 0.0, "f1": 0.0}
with torch.no_grad():
    for imgs, masks in val_loader:
        imgs, masks = imgs.to(device), masks.to(device)
        logits = model(imgs)
        batch_metrics = compute_metrics(logits, masks)
        for k in final_metrics:
            final_metrics[k] += batch_metrics[k] * imgs.size(0)

for k in final_metrics:
    final_metrics[k] /= len(val_ds)

print("=== Final Validation Metrics (Best Checkpoint) ===")
for k, v in final_metrics.items():
    print(f"{k.upper()}: {v:.4f}")
# Out:
# === Final Validation Metrics (Best Checkpoint) ===
# IOU: 0.8039
# PRECISION: 0.9033
# RECALL: 0.8807
# F1: 0.8912

# %%
Version1_scratch_results = {
    "Model": "from-scratch U-Net",
    "iou": final_metrics["iou"],
    "precision": final_metrics["precision"],
    "recall": final_metrics["recall"],
    "f1": final_metrics["f1"],
}
Version1_scratch_results
# Out:
# {'Model': 'from-scratch U-Net',
#  'iou': 0.8039437181673651,
#  'precision': 0.9033107926416644,
#  'recall': 0.8806732788585881,
#  'f1': 0.8912326896165866}

# %% [markdown]
# ## Step 4.5 — Loss/IoU Curves

# %%
fig, axes = plt.subplots(1, 2, figsize=(12,4))
axes[0].plot(history["train_loss"], label="train")
axes[0].plot(history["val_loss"], label="val")
axes[0].set_title("Loss"); axes[0].legend()
axes[1].plot(history["val_iou"], label="val IoU", color="green")
axes[1].set_title("Validation IoU"); axes[1].legend()
plt.tight_layout()
plt.savefig("training_curves.png")
plt.show()

# %% [markdown]
# ## Step 4.6 — Prediction Visualizations

# %%
model.eval()
imgs, masks = next(iter(val_loader))
imgs, masks = imgs.to(device), masks.to(device)
with torch.no_grad():
    preds = torch.sigmoid(model(imgs)) > 0.5

fig, axes = plt.subplots(4, 3, figsize=(10, 12))
for i in range(4):
    rgb = imgs[i, [3,2,1]].cpu().permute(1,2,0).numpy()
    rgb = (rgb - rgb.min()) / (rgb.max() - rgb.min() + 1e-8)
    axes[i,0].imshow(rgb); axes[i,0].set_title("Input (RGB)"); axes[i,0].axis('off')
    axes[i,1].imshow(masks[i,0].cpu(), cmap='gray'); axes[i,1].set_title("Ground Truth"); axes[i,1].axis('off')
    axes[i,2].imshow(preds[i,0].cpu(), cmap='gray'); axes[i,2].set_title("Prediction"); axes[i,2].axis('off')
plt.tight_layout()
plt.savefig("prediction_samples.png", dpi=100)
plt.show()

# %% [markdown]
# # Step 5: Pretrained Model — Adapting 12-Channel Input
#
# `segmentation_models_pytorch` (SMP) natively supports non-RGB input via the `in_channels` argument. When `in_channels != 3`, SMP does **not** randomly reinitialize the first convolution — it takes the pretrained 3-channel ImageNet weights and replicates/tiles them cyclically across the requested channel count (then rescales), so the new channels start from meaningful pretrained low-level filters (edges, textures, gradients) rather than random noise. This is generally a better starting point than zero-init, especially for a small dataset like here (306 training images), since it preserves useful inductive bias from large-scale pretraining while still allowing the extra channels to specialize during fine-tuning.
#
# We use a ResNet34 encoder (a good balance of capacity vs. training cost for ~300 training images) with a U-Net decoder, matching the Version 1 architecture family for a fair comparison.

# %%
def build_pretrained_model():
    model = smp.Unet(
        encoder_name="resnet34",
        encoder_weights="imagenet",
        in_channels=12,
        classes=1,
        activation=None,  # raw logits; sigmoid applied in loss/metrics like Version 1
    )
    return model

model = build_pretrained_model().to(device)

# Sanity check
x = torch.randn(4, 12, 128, 128).to(device)
with torch.no_grad():
    out = model(x)
print("Output shape:", out.shape)

n_params = sum(p.numel() for p in model.parameters())
n_trainable = sum(p.numel() for p in model.parameters() if p.requires_grad)
print(f"Total parameters: {n_params:,}")
print(f"Trainable parameters: {n_trainable:,}")
# Out:
# Output shape: torch.Size([4, 1, 128, 128])
# Total parameters: 24,464,593
# Trainable parameters: 24,464,593

# %% [markdown]
# # Step 6: Fine-Tuning Strategy
#
# Two strategies are compared on the same pretrained architecture, using identical hyperparameters wherever possible so the comparison isolates the effect of the fine-tuning schedule itself:
#
# - **Strategy A — Full fine-tuning:** unfreeze the entire model from epoch 1, train end-to-end with a single (lower-than-scratch) learning rate.
# - **Strategy B — Encoder-frozen warmup, then unfreeze:** freeze the pretrained encoder for the first `WARMUP_EPOCHS` epochs (train only the randomly-initialized decoder/head), then unfreeze the encoder and continue training the whole network at a lower learning rate.
#
# Both strategies reuse the same `BCEDiceLoss`, the same `compute_metrics`, and the same early-stopping logic as Version 1.

# %% [markdown]
# ## Step 6.1 — Trainig Strategy

# %%
def train_model(model, train_loader, val_loader, num_epochs, lr,
                 encoder_freeze_epochs=0, patience=15,
                 checkpoint_path="best_model.pth", verbose=True):
    """
    Generic training loop with optional encoder-freeze warmup and early stopping.

    encoder_freeze_epochs > 0  -> Strategy B (freeze encoder for N epochs, then unfreeze)
    encoder_freeze_epochs == 0 -> Strategy A (full fine-tuning from epoch 1)
    """
    model = model.to(device)
    criterion = BCEDiceLoss(bce_weight=0.5)

    if encoder_freeze_epochs > 0:
        for p in model.encoder.parameters():
            p.requires_grad = False
        optimizer = torch.optim.Adam(
            filter(lambda p: p.requires_grad, model.parameters()), lr=lr
        )
    else:
        optimizer = torch.optim.Adam(model.parameters(), lr=lr)

    scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(
        optimizer, mode='min', factor=0.5, patience=3
    )

    best_val_iou = 0.0
    epochs_no_improve = 0
    history = {"train_loss": [], "val_loss": [], "val_iou": []}
    unfrozen = (encoder_freeze_epochs == 0)

    for epoch in range(num_epochs):
        # Unfreeze encoder once warmup is done
        if not unfrozen and epoch == encoder_freeze_epochs:
            for p in model.encoder.parameters():
                p.requires_grad = True
            optimizer = torch.optim.Adam(model.parameters(), lr=lr * 0.1)
            scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(
                optimizer, mode='min', factor=0.5, patience=3
            )
            unfrozen = True
            if verbose:
                print(f"--- Epoch {epoch+1}: encoder unfrozen, LR reduced to {lr*0.1:.2e} ---")

        # Train
        model.train()
        train_loss = 0.0
        for imgs, masks in train_loader:
            imgs, masks = imgs.to(device), masks.to(device)
            optimizer.zero_grad()
            logits = model(imgs)
            loss = criterion(logits, masks)
            loss.backward()
            optimizer.step()
            train_loss += loss.item() * imgs.size(0)
        train_loss /= len(train_loader.dataset)

        # Validate
        model.eval()
        val_loss = 0.0
        metric_accum = {"iou": 0.0, "precision": 0.0, "recall": 0.0, "f1": 0.0}
        with torch.no_grad():
            for imgs, masks in val_loader:
                imgs, masks = imgs.to(device), masks.to(device)
                logits = model(imgs)
                loss = criterion(logits, masks)
                val_loss += loss.item() * imgs.size(0)
                bm = compute_metrics(logits, masks)
                for k in metric_accum:
                    metric_accum[k] += bm[k] * imgs.size(0)
        val_loss /= len(val_loader.dataset)
        for k in metric_accum:
            metric_accum[k] /= len(val_loader.dataset)

        scheduler.step(val_loss)

        history["train_loss"].append(train_loss)
        history["val_loss"].append(val_loss)
        history["val_iou"].append(metric_accum["iou"])

        if verbose:
            print(f"Epoch {epoch+1}/{num_epochs} | "
                  f"Train Loss: {train_loss:.4f} | Val Loss: {val_loss:.4f} | "
                  f"Val IoU: {metric_accum['iou']:.4f} | Val F1: {metric_accum['f1']:.4f} | "
                  f"Val Precision: {metric_accum['precision']:.4f} | Val Recall: {metric_accum['recall']:.4f}")

        if metric_accum["iou"] > best_val_iou:
            best_val_iou = metric_accum["iou"]
            epochs_no_improve = 0
            torch.save(model.state_dict(), checkpoint_path)
        else:
            epochs_no_improve += 1
            if epochs_no_improve >= patience:
                if verbose:
                    print(f"\nEarly stopping at epoch {epoch+1} "
                          f"(no val IoU improvement for {patience} epochs).")
                break

    return history, best_val_iou

# %% [markdown]
# ## Step 6.2 — Strategy A: full fine-tuning from epoch 1

# %%
NUM_EPOCHS = 100
PATIENCE = 15

print("=" * 60)
print("STRATEGY A: Full fine-tuning (no freeze)")
print("=" * 60)
model_a = build_pretrained_model()
history_a, best_iou_a = train_model(
    model_a, train_loader, val_loader,
    num_epochs=NUM_EPOCHS, lr=1e-4,
    encoder_freeze_epochs=0, patience=PATIENCE,
    checkpoint_path="best_pretrained_full_finetune.pth"
)
print(f"\nStrategy A best Val IoU: {best_iou_a:.4f}")
# Out:
# ============================================================
# STRATEGY A: Full fine-tuning (no freeze)
# ============================================================
# Epoch 1/100 | Train Loss: 0.6435 | Val Loss: 0.5739 | Val IoU: 0.4467 | Val F1: 0.6140 | Val Precision: 0.5914 | Val Recall: 0.6567
# Epoch 2/100 | Train Loss: 0.5487 | Val Loss: 0.5146 | Val IoU: 0.5787 | Val F1: 0.7320 | Val Precision: 0.6682 | Val Recall: 0.8120
# Epoch 3/100 | Train Loss: 0.4917 | Val Loss: 0.4618 | Val IoU: 0.6708 | Val F1: 0.8023 | Val Precision: 0.7991 | Val Recall: 0.8075
# Epoch 4/100 | Train Loss: 0.4559 | Val Loss: 0.4363 | Val IoU: 0.6945 | Val F1: 0.8194 | Val Precision: 0.7946 | Val Recall: 0.8478
# Epoch 40/100 | Train Loss: 0.2130 | Val Loss: 0.2766 | Val IoU: 0.8269 | Val F1: 0.9051 | Val Precision: 0.9095 | Val Recall: 0.9022
# Epoch 41/100 | Train Loss: 0.2175 | Val Loss: 0.2767 | Val IoU: 0.8232 | Val F1: 0.9029 | Val Precision: 0.9272 | Val Recall: 0.8809
# Epoch 42/100 | Train Loss: 0.2184 | Val Loss: 0.2814 | Val IoU: 0.8135 | Val F1: 0.8967 | Val Precision: 0.8967 | Val Recall: 0.8976
# Epoch 43/100 | Train Loss: 0.2166 | Val Loss: 0.2838 | Val IoU: 0.8170 | Val F1: 0.8989 | Val Precision: 0.9138 | Val Recall: 0.8856
# Epoch 44/100 | Train Loss: 0.2260 | Val Loss: 0.2823 | Val IoU: 0.8167 | Val F1: 0.8990 | Val Precision: 0.8961 | Val Recall: 0.9033
# Epoch 45/100 | Train Loss: 0.2082 | Val Loss: 0.2848 | Val IoU: 0.8156 | Val F1: 0.8982 | Val Precision: 0.9240 | Val Recall: 0.8752
# Epoch 46/100 | Train Loss: 0.2082 | Val Loss: 0.2787 | Val IoU: 0.8247 | Val F1: 0.9038 | Val Precision: 0.8934 | Val Recall: 0.9164
# Epoch 47/100 | Train Loss: 0.2002 | Val Loss: 0.2771 | Val IoU: 0.8258 | Val F1: 0.9045 | Val Precision: 0.9057 | Val Recall: 0.9050
# Epoch 48/100 | Train Loss: 0.1981 | Val Loss: 0.2792 | Val IoU: 0.8244 | Val F1: 0.9035 | Val Precision: 0.9086 | Val Recall: 0.9005
# Epoch 49/100 | Train Loss: 0.1949 | Val Loss: 0.2768 | Val IoU: 0.8241 | Val F1: 0.9033 | Val Precision: 0.9216 | Val Recall: 0.8872
# Epoch 50/100 | Train Loss: 0.1921 | Val Loss: 0.2752 | Val IoU: 0.8259 | Val F1: 0.9044 | Val Precision: 0.9149 | Val Recall: 0.8956
# Epoch 51/100 | Train Loss: 0.1946 | Val Loss: 0.2756 | Val IoU: 0.8252 | Val F1: 0.9040 | Val Precision: 0.9256 | Val Recall: 0.8848
# Epoch 52/100 | Train Loss: 0.1977 | Val Loss: 0.2742 | Val IoU: 0.8263 | Val F1: 0.9047 | Val Precision: 0.9178 | Val Recall: 0.8935
# Epoch 53/100 | Train Loss: 0.1898 | Val Loss: 0.2757 | Val IoU: 0.8258 | Val F1: 0.9044 | Val Precision: 0.9216 | Val Recall: 0.8893
# Epoch 54/100 | Train Loss: 0.1917 | Val Loss: 0.2749 | Val IoU: 0.8268 | Val F1: 0.9050 | Val Precision: 0.9192 | Val Recall: 0.8925
#
# Early stopping at epoch 54 (no val IoU improvement for 15 epochs).
#
# Strategy A best Val IoU: 0.8299

# %% [markdown]
# ## Step 6.2 — Strategy B: encoder-frozen warmup, then unfreeze

# %%
print("=" * 60)
print("STRATEGY B: Frozen-encoder warmup (5 epochs) then unfreeze")
print("=" * 60)
model_b = build_pretrained_model()
history_b, best_iou_b = train_model(
    model_b, train_loader, val_loader,
    num_epochs=NUM_EPOCHS, lr=1e-3,
    encoder_freeze_epochs=5, patience=PATIENCE,
    checkpoint_path="best_pretrained_warmup_finetune.pth"
)
print(f"\nStrategy B best Val IoU: {best_iou_b:.4f}")
# Out:
# ============================================================
# STRATEGY B: Frozen-encoder warmup (5 epochs) then unfreeze
# ============================================================
# Epoch 1/100 | Train Loss: 0.6014 | Val Loss: 0.8549 | Val IoU: 0.3856 | Val F1: 0.5456 | Val Precision: 0.3931 | Val Recall: 0.9460
# Epoch 2/100 | Train Loss: 0.5171 | Val Loss: 0.4665 | Val IoU: 0.5813 | Val F1: 0.7316 | Val Precision: 0.6590 | Val Recall: 0.8252
# Epoch 3/100 | Train Loss: 0.4709 | Val Loss: 0.4386 | Val IoU: 0.5980 | Val F1: 0.7452 | Val Precision: 0.7076 | Val Recall: 0.7912
# Epoch 4/100 | Train Loss: 0.4593 | Val Loss: 0.4731 | Val IoU: 0.5961 | Val F1: 0.7459 | Val Precision: 0.6701 | Val Recall: 0.8429
# Epoch 5/100 | Train Loss: 0.4227 | Val Loss: 0.4266 | Val IoU: 0.6499 | Val F1: 0.7862 | Val Precision: 0.8844 | Val Recall: 0.7103
# --- Epoch 6: encoder unfrozen, LR reduced to 1.00e-04 ---
# Epoch 6/100 | Train Loss: 0.4148 | Val Loss: 0.3954 | Val IoU: 0.6779 | Val F1: 0.8073 | Val Precision: 0.7693 | Val Recall: 0.8565
# Epoch 7/100 | Train Loss: 0.3963 | Val Loss: 0.3624 | Val IoU: 0.7333 | Val F1: 0.8457 | Val Precision: 0.8809 | Val Recall: 0.8155
# Epoch 8/100 | Train Loss: 0.3656 | Val Loss: 0.3551 | Val IoU: 0.7433 | Val F1: 0.8523 | Val Precision: 0.8857 | Val Recall: 0.8239
# Epoch 9/100 | Train Loss: 0.3497 | Val Loss: 0.3579 | Val IoU: 0.7394 | Val F1: 0.8497 | Val Precision: 0.8584 | Val Recall: 0.8431
# Epoch 10/100 | Train Loss: 0.3428 | Val Loss: 0.3484 | Val IoU: 0.7561 | Val F1: 0.8606 | Val Precision: 0.9038 | Val Recall: 0.8239
# Epoch 11/100 | Train Loss: 0.3331 | Val Loss: 0.3424 | Val IoU: 0.7633 | Val F1: 0.8654 | Val Precision: 0.8911 | Val Recall: 0.8439
# Epoch 12/100 | Train Loss: 0.3330 | Val Loss: 0.3480 | Val IoU: 0.7462 | Val F1: 0.8542 | Val Precision: 0.8507 | Val Recall: 0.8606
# Epoch 13/100 | Train Loss: 0.3271 | Val Loss: 0.3415 | Val IoU: 0.7527 | Val F1: 0.8584 | Val Precision: 0.9049 | Val Recall: 0.8184
# Epoch 14/100 | Train Loss: 0.3154 | Val Loss: 0.3347 | Val IoU: 0.7641 | Val F1: 0.8661 | Val Precision: 0.8817 | Val Recall: 0.8532
# Epoch 15/100 | Train Loss: 0.3073 | Val Loss: 0.3335 | Val IoU: 0.7564 | Val F1: 0.8611 | Val Precision: 0.8943 | Val Recall: 0.8324
# Epoch 69/100 | Train Loss: 0.2144 | Val Loss: 0.2867 | Val IoU: 0.8087 | Val F1: 0.8940 | Val Precision: 0.9197 | Val Recall: 0.8711
# Epoch 70/100 | Train Loss: 0.2112 | Val Loss: 0.2858 | Val IoU: 0.8098 | Val F1: 0.8947 | Val Precision: 0.9204 | Val Recall: 0.8718
# Epoch 71/100 | Train Loss: 0.2104 | Val Loss: 0.2860 | Val IoU: 0.8082 | Val F1: 0.8938 | Val Precision: 0.9221 | Val Recall: 0.8685
# Epoch 72/100 | Train Loss: 0.2099 | Val Loss: 0.2859 | Val IoU: 0.8088 | Val F1: 0.8942 | Val Precision: 0.9293 | Val Recall: 0.8628
# Epoch 73/100 | Train Loss: 0.2076 | Val Loss: 0.2847 | Val IoU: 0.8088 | Val F1: 0.8942 | Val Precision: 0.9291 | Val Recall: 0.8630
# Epoch 74/100 | Train Loss: 0.2122 | Val Loss: 0.2835 | Val IoU: 0.8097 | Val F1: 0.8947 | Val Precision: 0.9256 | Val Recall: 0.8671
#
# Early stopping at epoch 74 (no val IoU improvement for 15 epochs).
#
# Strategy B best Val IoU: 0.8122

# %% [markdown]
# # Step 7: Fine-Tuning Strategy Results Comparison
#
# Compare the two strategies directly on validation IoU before picking a winner to compare against the Version 1 scratch model.

# %%
fig, axes = plt.subplots(1, 2, figsize=(13, 4))
axes[0].plot(history_a["val_iou"], label="Strategy A: Full fine-tune")
axes[0].plot(history_b["val_iou"], label="Strategy B: Warmup then unfreeze")
axes[0].set_title("Validation IoU per epoch")
axes[0].set_xlabel("Epoch"); axes[0].set_ylabel("IoU")
axes[0].legend()

axes[1].plot(history_a["val_loss"], label="Strategy A val loss")
axes[1].plot(history_b["val_loss"], label="Strategy B val loss")
axes[1].set_title("Validation Loss per epoch")
axes[1].set_xlabel("Epoch"); axes[1].set_ylabel("Loss")
axes[1].legend()

plt.tight_layout()
plt.savefig("finetune_strategy_comparison.png", dpi=100)
plt.show()

print(f"Strategy A (full fine-tune) best Val IoU:      {best_iou_a:.4f}")
print(f"Strategy B (warmup then unfreeze) best Val IoU: {best_iou_b:.4f}")

better_strategy = "A (Full fine-tune)" if best_iou_a >= best_iou_b else "B (Warmup then unfreeze)"
print(f"\nBetter fine-tuning strategy for this dataset: Strategy {better_strategy}")
# Out:
# Strategy A (full fine-tune) best Val IoU:      0.8299
# Strategy B (warmup then unfreeze) best Val IoU: 0.8122
#
# Better fine-tuning strategy for this dataset: Strategy A (Full fine-tune)

# %% [markdown]
# # Step 8: Final Evaluation of the Best Pretrained Model

# %% [markdown]
# ## Step 8.1 — Final Reported Metrics

# %%
# Load whichever strategy performed better
best_checkpoint = ("best_pretrained_warmup_finetune.pth"
                    if best_iou_b >= best_iou_a
                    else "best_pretrained_full_finetune.pth")

final_model = build_pretrained_model().to(device)
final_model.load_state_dict(torch.load(best_checkpoint, map_location=device))
final_model.eval()

final_metrics = {"iou": 0.0, "precision": 0.0, "recall": 0.0, "f1": 0.0}
with torch.no_grad():
    for imgs, masks in val_loader:
        imgs, masks = imgs.to(device), masks.to(device)
        logits = final_model(imgs)
        bm = compute_metrics(logits, masks)
        for k in final_metrics:
            final_metrics[k] += bm[k] * imgs.size(0)
for k in final_metrics:
    final_metrics[k] /= len(val_ds)

print("=== Final Validation Metrics — Best Pretrained Model ===")
print(f"Checkpoint used: {best_checkpoint}")
for k, v in final_metrics.items():
    print(f"{k.upper()}: {v:.4f}")
# Out:
# === Final Validation Metrics — Best Pretrained Model ===
# Checkpoint used: best_pretrained_full_finetune.pth
# IOU: 0.8299
# PRECISION: 0.9154
# RECALL: 0.9005
# F1: 0.9070

# %%
Version2_pretrained_results = {
    "Model": f"Pretrained ResNet34 U-Net",
    "iou": final_metrics["iou"],
    "precision": final_metrics["precision"],
    "recall": final_metrics["recall"],
    "f1": final_metrics["f1"],
}

Version2_pretrained_results
# Out:
# {'Model': 'Pretrained ResNet34 U-Net',
#  'iou': 0.829927438733091,
#  'precision': 0.9153771590688846,
#  'recall': 0.9005319010170049,
#  'f1': 0.9069632012133364}

# %% [markdown]
# ## Step 8.2 — Predictions Visualizations

# %%
final_model.eval()
imgs, masks = next(iter(val_loader))
imgs, masks = imgs.to(device), masks.to(device)
with torch.no_grad():
    preds = torch.sigmoid(final_model(imgs)) > 0.5

fig, axes = plt.subplots(4, 3, figsize=(10, 12))
for i in range(4):
    rgb = imgs[i, [3, 2, 1]].cpu().permute(1, 2, 0).numpy()
    rgb = (rgb - rgb.min()) / (rgb.max() - rgb.min() + 1e-8)
    axes[i, 0].imshow(rgb); axes[i, 0].set_title("Input (RGB)"); axes[i, 0].axis('off')
    axes[i, 1].imshow(masks[i, 0].cpu(), cmap='gray'); axes[i, 1].set_title("Ground Truth"); axes[i, 1].axis('off')
    axes[i, 2].imshow(preds[i, 0].cpu(), cmap='gray'); axes[i, 2].set_title("Prediction (Pretrained)"); axes[i, 2].axis('off')
plt.tight_layout()
plt.savefig("pretrained_prediction_samples.png", dpi=100)
plt.show()

# %% [markdown]
# # Step 9: Final Comparison — Scratch U-Net (Version 1) vs Pretrained U-Net (Version 2)
#
# Required deliverable: a comparison table using identical metrics for both models, evaluated on the same validation split.

# %%
comparison_df = pd.DataFrame([Version1_scratch_results, Version2_pretrained_results])
comparison_df = comparison_df[["Model", "iou", "precision", "recall", "f1"]]
comparison_df.columns = ["Model", "IoU", "Precision", "Recall", "F1"]
comparison_df
# Out:
#                        Model       IoU  Precision    Recall        F1
# 0         from-scratch U-Net  0.803944   0.903311  0.880673  0.891233
# 1  Pretrained ResNet34 U-Net  0.829927   0.915377  0.900532  0.906963

# %%
iou_delta = Version2_pretrained_results["iou"] - Version1_scratch_results["iou"]
print(f"IoU change vs Version 1 scratch U-Net: {iou_delta:+.4f}")
if iou_delta > 0:
    print("Pretrained model achieved a measurably higher validation IoU")
else:
    print("Pretrained model did NOT beat the scratch baseline on IoU")
# Out:
# IoU change vs Version 1 scratch U-Net: +0.0260
# Pretrained model achieved a measurably higher validation IoU
